# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Update file PATH HERE from LOCAL DRIVE

# %%
file1 = r"C:\Users\Lenovo\Downloads\restaurants_data.csv"
file2 = r"C:\Users\Lenovo\Downloads\restaurants_details.csv"

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# %%
df1
# Out:
#      Unnamed: 0                        name  \
# 0             0          Cafe Delhi Heights
# 1             1                        Ouro
# 2             2            The Bier Library
# 3             3              Bombay Borough
# 4             4                      Pangeo
# ..          ...                         ...
# 995         995   Chaayos Chai+Snacks=Relax
# 996         996          Atithi Aramane Veg
# 997         997  Vishal Sweets & Restaurant
# 998         998           Udupi Vaibhav Veg
# 999         999    Kerala Panoor Restaurant
#
#                                location  price_for_two  \
# 0             Forum Rex Walk, Bangalore           1500
# 1             Forum Rex Walk, Bangalore           3000
# 2      Koramangala 6th Block, Bangalore           1800
# 3              Richmond Road, Bangalore           2000
# 4             Forum Rex Walk, Bangalore           3500
# ..                                  ...            ...
# ...

# %%
df1.replace('New',0.0,inplace = True)

# %%
df1.replace('-',0.0,inplace = True)

# %%
df1
# Out:
#      Unnamed: 0                        name  \
# 0             0          Cafe Delhi Heights
# 1             1                        Ouro
# 2             2            The Bier Library
# 3             3              Bombay Borough
# 4             4                      Pangeo
# ..          ...                         ...
# 995         995   Chaayos Chai+Snacks=Relax
# 996         996          Atithi Aramane Veg
# 997         997  Vishal Sweets & Restaurant
# 998         998           Udupi Vaibhav Veg
# 999         999    Kerala Panoor Restaurant
#
#                                location  price_for_two  \
# 0             Forum Rex Walk, Bangalore           1500
# 1             Forum Rex Walk, Bangalore           3000
# 2      Koramangala 6th Block, Bangalore           1800
# 3              Richmond Road, Bangalore           2000
# 4             Forum Rex Walk, Bangalore           3500
# ..                                  ...            ...
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0         0
# name               0
# location           0
# price_for_two      0
# cuisines           0
# rating             0
# restaurant_link    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1000 non-null   int64
#  1   name             1000 non-null   object
#  2   location         1000 non-null   object
#  3   price_for_two    1000 non-null   int64
#  4   cuisines         1000 non-null   object
#  5   rating           1000 non-null   object
#  6   restaurant_link  1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
df1['rating'] = df1['rating'].astype(float)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                 0
# name                       0
# latitude                  26
# longitude                 26
# delivery_review_number     0
# location                   0
# dtype: int64

# %%
df2 = df2.drop(['latitude', 'longitude'],axis = 1)

# %%
df2
# Out:
#      Unnamed: 0                        name delivery_review_number  \
# 0             0          Cafe Delhi Heights                     44
# 1             1                        Ouro                      0
# 2             2            The Bier Library                    695
# 3             3              Bombay Borough                     55
# 4             4                      Pangeo                      0
# ..          ...                         ...                    ...
# 995         995   Chaayos Chai+Snacks=Relax                    909
# 996         996          Atithi Aramane Veg                  4,583
# 997         997  Vishal Sweets & Restaurant                  9,137
# 998         998           Udupi Vaibhav Veg                  1,258
# 999         999    Kerala Panoor Restaurant                  23.7K
#
#                                location
# 0             Forum Rex Walk, Bangalore
# 1             Forum Rex Walk, Bangalore
# ...

# %%
df = pd.merge(df1, df2, on = 'Unnamed: 0', how = 'left')

# %%
df
# Out:
#      Unnamed: 0                      name_x  \
# 0             0          Cafe Delhi Heights
# 1             1                        Ouro
# 2             2            The Bier Library
# 3             3              Bombay Borough
# 4             4                      Pangeo
# ..          ...                         ...
# 995         995   Chaayos Chai+Snacks=Relax
# 996         996          Atithi Aramane Veg
# 997         997  Vishal Sweets & Restaurant
# 998         998           Udupi Vaibhav Veg
# 999         999    Kerala Panoor Restaurant
#
#                              location_x  price_for_two  \
# 0             Forum Rex Walk, Bangalore           1500
# 1             Forum Rex Walk, Bangalore           3000
# 2      Koramangala 6th Block, Bangalore           1800
# 3              Richmond Road, Bangalore           2000
# 4             Forum Rex Walk, Bangalore           3500
# ..                                  ...            ...
# ...

# %%
df = df.drop(['name_y', 'location_y', 'restaurant_link'], axis=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name_x', 'location_x', 'price_for_two', 'cuisines',
#        'rating', 'delivery_review_number'],
#       dtype='object')

# %%
# Created new column as per requirement

df['Price_for_one'] = df['price_for_two']/2

# %%
# Renamed columns

df = df.rename(columns = {'Unnamed: 0':'Restaurant_id', 'name_x':'Name', 'location_x':'Location', 'price_for_two':'Price_for_two', 'cuisines':'Cuisines',
       'rating':'Rating', 'delivery_review_number':'Delivery_review_number'})

# %%
df
# Out:
#      Restaurant_id                        Name  \
# 0                0          Cafe Delhi Heights
# 1                1                        Ouro
# 2                2            The Bier Library
# 3                3              Bombay Borough
# 4                4                      Pangeo
# ..             ...                         ...
# 995            995   Chaayos Chai+Snacks=Relax
# 996            996          Atithi Aramane Veg
# 997            997  Vishal Sweets & Restaurant
# 998            998           Udupi Vaibhav Veg
# 999            999    Kerala Panoor Restaurant
#
#                                Location  Price_for_two  \
# 0             Forum Rex Walk, Bangalore           1500
# 1             Forum Rex Walk, Bangalore           3000
# 2      Koramangala 6th Block, Bangalore           1800
# 3              Richmond Road, Bangalore           2000
# 4             Forum Rex Walk, Bangalore           3500
# ..                                  ...            ...
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_id', 'Name', 'Location', 'Price_for_two', 'Cuisines',
#        'Rating', 'Delivery_review_number', 'Price_for_one'],
#       dtype='object')

# %%
#Converted delivery_review_number to float from object

df['Delivery_review_number'] = df['Delivery_review_number'].apply(lambda x: float(x.replace(',', '').replace('K', '')) * 1000 if 'K' in x else float(x.replace(',', '')))

# %%
df
# Out:
#      Restaurant_id                        Name  \
# 0                0          Cafe Delhi Heights
# 1                1                        Ouro
# 2                2            The Bier Library
# 3                3              Bombay Borough
# 4                4                      Pangeo
# ..             ...                         ...
# 995            995   Chaayos Chai+Snacks=Relax
# 996            996          Atithi Aramane Veg
# 997            997  Vishal Sweets & Restaurant
# 998            998           Udupi Vaibhav Veg
# 999            999    Kerala Panoor Restaurant
#
#                                Location  Price_for_two  \
# 0             Forum Rex Walk, Bangalore           1500
# 1             Forum Rex Walk, Bangalore           3000
# 2      Koramangala 6th Block, Bangalore           1800
# 3              Richmond Road, Bangalore           2000
# 4             Forum Rex Walk, Bangalore           3500
# ..                                  ...            ...
# ...

# %%
numerics = df.select_dtypes(np.number).columns.tolist()

# %%
df[numerics].corr()
# Out:
#                         Restaurant_id  Price_for_two    Rating  \
# Restaurant_id                1.000000      -0.614998 -0.600631
# Price_for_two               -0.614998       1.000000  0.456463
# Rating                      -0.600631       0.456463  1.000000
# Delivery_review_number       0.007280      -0.127933  0.157887
# Price_for_one               -0.614998       1.000000  0.456463
#
#                         Delivery_review_number  Price_for_one
# Restaurant_id                         0.007280      -0.614998
# Price_for_two                        -0.127933       1.000000
# Rating                                0.157887       0.456463
# Delivery_review_number                1.000000      -0.127933
# Price_for_one                        -0.127933       1.000000

# %%
sns.heatmap(df[numerics].corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Boxplot for 'Price_for_one' to spot outliers

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Price_for_one'])
plt.title('Boxplot of Price for One')
plt.show()

# %% [markdown]
# ### Histogram for the distribution of 'Rating'

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], bins=20, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Count of Restaurants in each 'Location'

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Location', data=df, order=df['Location'].value_counts().index)
plt.title('Count of Restaurants by Location')
plt.xlabel('Count')
plt.ylabel('Location')
plt.show()

# %% [markdown]
# ### Scatter plot of 'Price_for_two' vs. 'Rating'

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Price_for_one', y='Rating', data=df, alpha=0.6)  # 'alpha' is for point transparency
plt.title('Scatter Plot of Price for one vs. Rating')
plt.xlabel('Price for One')
plt.ylabel('Rating')
plt.show()

# %%
#Pairplot for pairwise relationships
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Model

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
# Splitting the data into training , testing and validation sets
train_val_df,test_df = tts(df,test_size = 0.20, random_state = 42)
train_df, val_df = tts(train_val_df,test_size = 0.20,random_state = 42)

# %%
train_df
# Out:
#      Restaurant_id                            Name  \
# 390            390  Kairali Kitchen And Restaurant
# 847            847     Mahadev Pure Veg Restaurant
# 93              93                  Hard Rock Cafe
# 236            236              Down Town Tap Room
# 858            858   Haldiram's Sweets And Namkeen
# ..             ...                             ...
# 118            118               The Watering Hole
# 334            334       CUR8 - Four Seasons Hotel
# 409            409                       Bob's Bar
# 225            225       A2B - Adyar Ananda Bhavan
# 482            482                    Nasi And Mee
#
#                                      Location  Price_for_two  \
# 390                       Attibele, Bangalore           1000
# 847     ITPL Main Road, Whitefield, Bangalore            350
# 93                  St. Marks Road, Bangalore           2500
# 236                   Brigade Road, Bangalore           1700
# ...

# %%
inputs = df.columns[:-1]
inputs
# Out:
# Index(['Restaurant_id', 'Name', 'Location', 'Price_for_two', 'Cuisines',
#        'Rating', 'Delivery_review_number'],
#       dtype='object')

# %%
target = ['Price_for_one']
target
# Out:
# ['Price_for_one']

# %%
train_inputs = train_df[inputs]
train_outputs = train_df[target]
val_inputs = val_df[inputs]
val_outputs = val_df[target]
test_inputs = test_df[inputs]
test_outputs = test_df[target]

# %%
numeric = train_inputs.select_dtypes(np.number).columns.tolist()
categorical = train_inputs.select_dtypes('object').columns.tolist()

# %% [markdown]
# ### Preprocessing

# %%
#Scaling

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df[numeric])

# %%
train_inputs[numeric] = scaler.transform(train_inputs[numeric])
val_inputs[numeric] = scaler.transform(val_inputs[numeric])
test_inputs[numeric] = scaler.transform(test_inputs[numeric])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1416\2747897461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_inputs[numeric] = scaler.transform(train_inputs[numeric])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1416\2747897461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_inputs[numeric] = scaler.transform(val_inputs[numeric])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1416\2747897461.py:3: SettingWithCopyWarning:
# ...

# %%
#Encoding
from sklearn.preprocessing import OneHotEncoder

# %%
# Assuming 'categorical' is a list of your categorical column names
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore').fit(df[categorical])

# %%
encoded_cols = list(encoder.get_feature_names_out(categorical))

# %%
encoded_cols
# Out:
# ['Name_1 BHK - Bar House Kitchen',
#  'Name_1131 Bar + Kitchen By House Of Commons',
#  'Name_1522 - The Pub',
#  'Name_153 Biere Street',
#  'Name_154 Breakfast Club',
#  'Name_1882',
#  'Name_1947',
#  'Name_1By2 Cafe',
#  'Name_2 MOONS',
#  'Name_2 Rabbits Bakes',
#  'Name_21st Amendment Gastrobar',
#  'Name_24@43 - The Oterra',
#  'Name_46 Ounces',
#  'Name_46 Ounces Brewgarden',
#  'Name_9 Tables Restaurant',
#  'Name_99 Udupi Veg',
#  'Name_A2B - Adyar Ananda Bhavan',
#  "Name_AB's - Absolute Barbecues",
#  'Name_AGS Grand',
#  'Name_ATR Foods',
#  'Name_Abooz Cafe',
#  'Name_Acharjee Sweets And Snacks',
#  'Name_Aditya Sweets',
#  'Name_Ak Tiffen And Lunch',
#  'Name_Akanksha Kitchen',
#  'Name_Akhila Bakery And Tea World',
#  'Name_Al Halaal Tabrez',
#  'Name_Alchemy',
#  'Name_Alibabar Hari',
#  'Name_Altitude Kitchen & Bar',
#  'Name_Amal’s Biriyani',
#  'Name_Ambedo Kitchen|Taproom',
#  'Name_Amintiri',
#  "Name_Amma's Pastries",
#  'Name_Anand Sweets And Savouries',
# ...

# %%
train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical])
val_inputs[encoded_cols] = encoder.transform(val_inputs[categorical])
test_inputs[encoded_cols] = encoder.transform(test_inputs[categorical])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1416\2906662322.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1416\2906662322.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical])
# ...

# %%
train_inputs = train_inputs[numeric + encoded_cols]
val_inputs = val_inputs[numeric + encoded_cols]
test_inputs = test_inputs[numeric + encoded_cols]

# %% [markdown]
# ### Fitting and Evaluation

# %%
lin = LinearRegression()
lin.fit(train_inputs,train_outputs)
# Out:
# LinearRegression()

# %%
train_preds = lin.predict(train_inputs)
val_preds = lin.predict(val_inputs)

# %%
# Using Mean squared error

from sklearn.metrics import mean_squared_error as mse
mse(train_outputs,train_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 1.4499163818747688e-12

# %%
#r2_score
from sklearn.metrics import r2_score
r2_score(train_outputs,train_preds)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score
r2_score(val_outputs,val_preds)
# Out:
# 0.9999850546208703

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(train_outputs,train_preds)
# Out:
# 1.0030198893673514e-12

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(lin, train_inputs, train_outputs, cv=5)  # 5-fold cross-validation
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.99996809 0.99995587 0.99996262 0.99995275 0.99996639]
# Mean CV Score: 0.9999611442798721

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor as dtr
model = dtr()
model.fit(train_inputs,train_outputs)
# Out:
# DecisionTreeRegressor()

# %%
train_preds = model.predict(train_inputs)
val_preds = model.predict(val_inputs)

# %%
mse(train_outputs,train_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 0.0

# %%
mse(val_outputs,val_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.905694150420948

# %%
from sklearn.metrics import r2_score
r2_score(train_outputs,train_preds)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score
r2_score(val_outputs,val_preds)
# Out:
# 0.9997106565203553

# %% [markdown]
# ### HyperParameter Tuning

# %%
dt_model = dtr(max_depth = 100, random_state = 42)
dt_model.fit(train_inputs,train_outputs)
# Out:
# DecisionTreeRegressor(max_depth=100, random_state=42)

# %%
train_preds = model.predict(train_inputs)
val_preds = model.predict(val_inputs)

# %%
mse(train_outputs,train_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 0.0

# %%
mse(val_outputs,val_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.905694150420948

# %%
from sklearn.metrics import r2_score
r2_score(train_outputs,train_preds)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score
r2_score(val_outputs,val_preds)
# Out:
# 0.9997106565203553

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(dt_model, train_inputs, train_outputs, cv=5)  # 5-fold cross-validation
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.99698205 0.9974235  0.99959213 0.99241137 1.        ]
# Mean CV Score: 0.9972818091922511

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor()
random_forest_model.fit(train_inputs,train_outputs)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
models = {'Random Forest': random_forest_model}

# %%
train_preds = model.predict(train_inputs)
val_preds = model.predict(val_inputs)

# %%
from joblib import dump, load

# %%
dump(random_forest_model, 'random_forest_model.joblib')

random_forest_model = load('random_forest_model.joblib')

# %%
mse(train_outputs,train_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 0.0

# %%
mse(val_outputs,val_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.905694150420948

# %%
from sklearn.metrics import r2_score
r2_score(train_outputs,train_preds)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score
r2_score(val_outputs,val_preds)
# Out:
# 0.9997106565203553

# %% [markdown]
# ### HyperParameter Tuning

# %%
random_forest_model = RandomForestRegressor(n_estimators = 5, max_depth = 20, random_state = 42)
random_forest_model.fit(train_inputs,train_outputs)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=20, n_estimators=5, random_state=42)

# %%
train_preds = random_forest_model.predict(train_inputs)
val_preds = random_forest_model.predict(val_inputs)

# %%
mse(train_outputs,train_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 6.126912966576235

# %%
mse(val_outputs,val_preds,squared = False)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 6.649718039135193

# %%
#r2_score
from sklearn.metrics import r2_score
r2_score(train_outputs,train_preds)
# Out:
# 0.9998254164003997

# %%
from sklearn.metrics import r2_score
r2_score(val_outputs,val_preds)
# Out:
# 0.9997952894881514

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(random_forest_model, train_inputs, train_outputs, cv=5)  # 5-fold cross-validation
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Cross-Validation Scores: [0.99788938 0.99913945 0.99787908 0.98344676 0.99929007]
# ...

# %% [markdown]
# ### KFold cross validation

# %%
# Concatenate DataFrames
combined_inputs = pd.concat([train_inputs, val_inputs], axis=0, ignore_index=True)
combined_outputs = pd.concat([train_outputs, val_outputs], axis=0, ignore_index=True)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

kf = KFold(n_splits=5,shuffle=True,random_state=30)

r2_scores = cross_val_score(random_forest_model, combined_inputs, combined_outputs, cv=kf, scoring='r2')

# Print the cross-validation scores
print("Cross-Validation R2 Scores:", r2_scores)
print("Mean R2:", r2_scores.mean())
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Cross-Validation R2 Scores: [0.99972279 0.99970538 0.98133619 0.99610422 0.9991965 ]
# ...

# %%
test_preds = random_forest_model.predict(test_inputs)

# %%
from sklearn.metrics import r2_score

train_r2 = r2_score(train_outputs, train_preds)
val_r2 = r2_score(val_outputs, val_preds)

print("Training R^2 Score:", train_r2)
print("Validation R^2 Score:", val_r2)
# Out:
# Training R^2 Score: 0.9998254164003997
# Validation R^2 Score: 0.9997952894881514

# %% [markdown]
# # Input function

# %%
def get_user_input():
    
    input_cuisine = input("Enter your preferred cuisine: ")

    input_location = input("Enter your preferred location: ")
    try:
        input_preferred_price = float(input("Enter your preferred price for 1: "))
    except ValueError:
        print("Please enter a valid number for price.")
        return None, None, None  # Return None if invalid input for price

    return input_cuisine, input_location, input_preferred_price

# Call the function to get user inputs
input_cuisine, input_location, input_preferred_price = get_user_input()

if input_cuisine and input_location and input_preferred_price is not None:
    print(f"Inputs - Cuisine: {input_cuisine}, Location: {input_location}, Preferred Price: {input_preferred_price}")
else:
    print("Invalid inputs received.")
# Out:
# Enter your preferred cuisine:  Thai
# Enter your preferred location:  HSR
# Enter your preferred price for 1:  1000
# Inputs - Cuisine: Thai, Location: HSR, Preferred Price: 1000.0

# %% [markdown]
# # Output 1

# %%
if input_cuisine is not None and input_location is not None and input_preferred_price is not None:
   
    location_filter = df['Location'].str.contains(input_location, case=False)
    df_location = df[location_filter]
    popular_cuisine = df_location['Cuisines'].mode().iloc[0]

    average_price = df_location['Price_for_one'].mean()

    most_popular_restaurant = df_location.loc[df_location['Rating'].idxmax()]
    most_popular_restaurant_name = most_popular_restaurant['Name']
    most_popular_restaurant_cuisine = most_popular_restaurant['Cuisines']

    
    cuisine_filter = df_location['Cuisines'].str.contains(input_cuisine, case=False)
    if not df_location[cuisine_filter].empty:
        most_popular_cuisine_restaurant = df_location[cuisine_filter].loc[df_location[cuisine_filter]['Rating'].idxmax()]
        most_popular_cuisine_restaurant_name = most_popular_cuisine_restaurant['Name']
    else:
        most_popular_cuisine_restaurant_name = "No restaurant found serving the specified cuisine"

    # Output part 1 results
    print(f"Popular Cuisine in {input_location}: {popular_cuisine}")
    print(f"Average Price for 1 in {input_location}: {average_price:.2f}")
    print(f"Most Popular Restaurant: {most_popular_restaurant_name} serving {most_popular_restaurant_cuisine}")
    print(f"Most Popular Restaurant serving {input_cuisine}: {most_popular_cuisine_restaurant_name}")
else:
    print("Invalid inputs received. Exiting the program.")
# Out:
# Popular Cuisine in HSR: American, Burger, Pizza, Continental, Bar Food, Desserts, Beverages
# Average Price for 1 in HSR: 487.50
# Most Popular Restaurant: Suku Japanese And Thai Restaurant serving Japanese, Thai
# Most Popular Restaurant serving Thai: Suku Japanese And Thai Restaurant

# %% [markdown]
# # Output 2

# %%
import pandas as pd

if input_cuisine is not None and input_location is not None and input_preferred_price is not None:
   
   
    input_data = {'Location': [input_location], 'Cuisines': [input_cuisine]}
    input_df = pd.DataFrame(input_data)
    
 
    input_df_encoded = pd.get_dummies(input_df, drop_first=True).reindex(columns=train_inputs.columns, fill_value=0)

    
    predicted_price = models['Random Forest'].predict(input_df_encoded)[0]

    # Price suggestion
    if input_preferred_price < predicted_price:
        suggested_price = input_preferred_price * 1.1  # Increase by 10%
        suggested_price = min(suggested_price, predicted_price)
    else:
        suggested_price = predicted_price

  
    print(f"Suggested Price for 1: {suggested_price:.2f}")

   
else:
    print("Invalid inputs received. Exiting the program.")
# Out:
# Suggested Price for 1: 500.00

# %%
import pandas as pd

if input_cuisine is not None and input_location is not None and input_preferred_price is not None:
    
    # Encoding the input for prediction
    input_data = {'Location': [input_location], 'Cuisines': [input_cuisine]}
    input_df = pd.DataFrame(input_data)
    

    input_df_encoded = pd.get_dummies(input_df, drop_first=True).reindex(columns=train_inputs.columns, fill_value=0)

    predicted_price = models['Random Forest'].predict(input_df_encoded)[0]

    # Price suggestion
    if input_preferred_price < predicted_price:
        suggested_price = input_preferred_price * 1.1  # Increase by 10%
        suggested_price = min(suggested_price, predicted_price)
    else:
        suggested_price = predicted_price

    cuisine_filter = df['Cuisines'].str.contains(input_cuisine, case=False)
    df_cuisine = df[cuisine_filter]

    affordable_locations = df_cuisine[df_cuisine['Price_for_one'] <= input_preferred_price]
    best_locations = affordable_locations.groupby('Location')['Rating'].mean().sort_values(ascending=False).index.tolist()

    if best_locations:
        suggested_location = best_locations[0]  # Suggest the top location
    else:
        suggested_location = "No suitable location found within the price range"

    #location suggestion
    print(f"Suggested Price for 1: {suggested_price:.2f}")
    print(f"Suggested Location for {input_cuisine} cuisine within your price range: {suggested_location}")

else:
    print("Invalid inputs received. Exiting the program.")
# Out:
# Suggested Price for 1: 500.00
# Suggested Location for Thai cuisine within your price range: Sahakara Nagar, Bangalore
